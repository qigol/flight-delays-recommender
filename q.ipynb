# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# # Data Loading and Cleaning

# %%
# Load Data
airlines = pd.read_csv("data/airlines.csv")
airports = pd.read_csv("data/airports.csv")
# flights = pd.read_csv("data/flights.csv", low_memory=False)

# %% [markdown]
# ### Fix 5-digit airport codes to standard 3-character IATA codes

# %%
#fix from https://github.com/lezandar/flights
aircode1 = pd.read_csv('data/L_AIRPORT.csv')
aircode2 = pd.read_csv('data/L_AIRPORT_ID.csv')

# Format the airport codes
aircode1 = aircode1.reset_index()
aircode2 = aircode2.reset_index()

# %%
aircodes = pd.merge(aircode1,aircode2,on='Description')
aircode_dict = dict(zip(aircodes['Code_y'].astype(str),aircodes['Code_x']))

# %%
# Make sure all Origin and departing airports are strings
flights['ORIGIN_AIRPORT'] = flights['ORIGIN_AIRPORT'].values.astype(str)
flights['DESTINATION_AIRPORT'] = flights['DESTINATION_AIRPORT'].values.astype(str)

# %%
for i in range(len(flights)):
    if len(flights['ORIGIN_AIRPORT'][i]) != 3:
        to_replace = flights['ORIGIN_AIRPORT'][i]
        value = aircode_dict[flights['ORIGIN_AIRPORT'][i]]
        flights = flights.replace(to_replace, value)

for i in range(len(flights)):
    if len(flights['DESTINATION_AIRPORT'][i]) != 3:
        to_replace = flights['DESTINATION_AIRPORT'][i]
        value = aircode_dict[flights['DESTINATION_AIRPORT'][i]]
        flights = flights.replace(to_replace, value)

# %% [markdown]
# ### Remove flights to and from BSM

# %%
flights_filtered_bsm = flights[
    (flights['ORIGIN_AIRPORT'] != 'BSM') &
    (flights['DESTINATION_AIRPORT'] != 'BSM')
]

# %%
len(flights) - len(flights_filtered_bsm)
# Out:
# 8035

# %%
flights_filtered_bsm.to_csv('data/flights_filtered_fixed.csv', index=False)

# %% [markdown]
# # Feature Engineering

# %%
flights = pd.read_csv("data/flights_filtered_fixed.csv", low_memory=False)

# %%
# Validate airports from flights to airports dataframe 
len(flights['ORIGIN_AIRPORT'].unique()) == len(airports)
# Out:
# True

# %% [markdown]
# ### Airport-level features:
#
# - `avg_flights_per_hour`: $\frac{\text{total flights for airport}}{\text{number of hours observed}}$
# - `avg_delay_rate`: P(delay)

# %%
filtered_flights = flights[
    (flights['CANCELLED'] == 0) &
    (flights['DIVERTED'] == 0) 
]


airports['avg_flights_per_hour'] = airports['IATA_CODE'].map(
    flights.assign(hour=filtered_flights['SCHEDULED_DEPARTURE']//100)
           .groupby(['ORIGIN_AIRPORT','hour'])
           .size()
           .groupby('ORIGIN_AIRPORT')
           .mean()
           .round()
)

airports['avg_flights_per_hour'] = airports['IATA_CODE'].map(
    flights.assign(hour=filtered_flights['SCHEDULED_DEPARTURE']//100)
           .groupby(['ORIGIN_AIRPORT','hour'])
           .size()
           .groupby('ORIGIN_AIRPORT')
           .mean()
           .round()
)

airport_delay = (
    filtered_flights
    .assign(delayed=lambda x: x['ARRIVAL_DELAY'] > 0)
    .groupby('ORIGIN_AIRPORT')['delayed']
    .mean()
)

airports['AVG_DELAY_RATE'] = airports['IATA_CODE'].map(airport_delay)

display(airports.head())
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE  avg_flights_per_hour  AVG_DELAY_RATE
# 0  40.65236  -75.44040                 247.0        0.370641
# 1  32.41132  -99.68190                 173.0        0.296327
# 2  35.04022 -106.60919                1036.0        0.365102
# 3  45.44906  -98.42183                  73.0        0.375171
# 4  31.53552  -84.19447                  95.0        0.364496

# %% [markdown]
# ### Route-level features
#
# - `schedule_padding` - $\text{average scheduled time} - \text{median flight time}$
#
# - `ave_delay` - $\frac{\sum \text{arrival delays}}{\text{num flights for the route}}$
#
# - `delay-rate` - P(delay)

# %%
route_df = (
    filtered_flights
    .groupby(['ORIGIN_AIRPORT','DESTINATION_AIRPORT'], as_index=False)
    .agg(
        NUM_FLIGHTS=('ELAPSED_TIME','size'),
        AVE_FLIGHT_TIME=('ELAPSED_TIME','mean'),
        MEDIAN_FLIGHT_TIME=('ELAPSED_TIME','median'),
        AVE_SCHEDULED_TIME=('SCHEDULED_TIME','mean')
    )
)

route_df['SCHEDULE_PADDING'] = (
    route_df['AVE_SCHEDULED_TIME'] -
    route_df['MEDIAN_FLIGHT_TIME']
)

route_df['AVE_DELAY'] = (
    filtered_flights
    .groupby(['ORIGIN_AIRPORT','DESTINATION_AIRPORT'])['ARRIVAL_DELAY']
    .mean()
    .values
)

delay_prob = (
    filtered_flights
    .assign(delayed=lambda x: x['ARRIVAL_DELAY'] > 0)
    .groupby(['ORIGIN_AIRPORT','DESTINATION_AIRPORT'])['delayed']
    .mean()
)

route_df['DELAY_RATE'] = delay_prob.values

display(route_df.head())
# Out:
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  NUM_FLIGHTS  AVE_FLIGHT_TIME  \
# 0            ABE                 ATL          974       127.198152
# 1            ABE                 DTW          770       101.715584
# 2            ABE                 ORD          722       130.110803
# 3            ABI                 DFW         2423        53.912918
# 4            ABQ                 ATL          890       174.517978
#
#    MEDIAN_FLIGHT_TIME  AVE_SCHEDULED_TIME  SCHEDULE_PADDING  AVE_DELAY  \
# 0               125.0          130.723819          5.723819   2.247433
# 1               100.0          104.267532          4.267532   8.276623
# 2               128.0          131.080332          3.080332   9.591413
# 3                51.0           56.896409          5.896409   2.536938
# 4               173.0          181.893258          8.893258  -0.601124
#
#    DELAY_RATE
# 0    0.335729
# 1    0.389610
# 2    0.397507
# 3    0.296327
# 4    0.215730

# %%
display(airports.sort_values(by='AVG_DELAY_RATE', ascending=False).head(10).reset_index(drop=True))

plt.bar(
    airports.sort_values(by='AVG_DELAY_RATE', ascending=False)['IATA_CODE'].head(10),
    airports.sort_values(by='AVG_DELAY_RATE', ascending=False)['AVG_DELAY_RATE'].head(10)
)
plt.show()
# Out:
#   IATA_CODE                                           AIRPORT         CITY  \
# 0       GST                                  Gustavus Airport     Gustavus
# 1       ADK                                      Adak Airport         Adak
# 2       PPG  Pago Pago International Airport (Tafuna Airport)    Pago Pago
# 3       ILG                                Wilmington Airport   Wilmington
# 4       AKN                               King Salmon Airport  King Salmon
# 5       STC                        St. Cloud Regional Airport     St Cloud
# 6       RHI                 Rhinelander-Oneida County Airport  Rhinelander
# 7       OME                                      Nome Airport         Nome
# 8       COD                      Yellowstone Regional Airport         Cody
# 9       PBG                 Plattsburgh International Airport  Plattsburgh
#
#   STATE COUNTRY  LATITUDE  LONGITUDE  avg_flights_per_hour  AVG_DELAY_RATE
# 0    AK     USA  58.42438 -135.70738                  76.0        0.671053
# 1    AK     USA  51.87796 -176.64603                  49.0        0.636364
# 2    AS     USA  14.33102 -170.71053                 116.0        0.632075
# 3    DE     USA  39.67872  -75.60653                  11.0        0.557895
# 4    AK     USA  58.67680 -156.64922                  63.0        0.507937
# 5    MN     USA  45.54532  -94.05834                  39.0        0.493506
# 6    WI     USA  45.63119  -89.46745                 128.0        0.490928
# 7    AK     USA  64.51220 -165.44525                 139.0        0.490506
# 8    WY     USA  44.52019 -109.02380                  68.0        0.480799
# 9    NY     USA       NaN        NaN                  73.0        0.467626

# %% [markdown]
# ## Congestion Detection

# %%
airport_hour_df = (
    filtered_flights
    .assign(hour=filtered_flights['SCHEDULED_DEPARTURE']//100)
    .groupby(['ORIGIN_AIRPORT','hour'])
    .agg(
        flights=('FLIGHT_NUMBER','size'),
        avg_delay=('ARRIVAL_DELAY','mean')
    )
    .reset_index()
)

# %%
airport_hour_df
# Out:
#      ORIGIN_AIRPORT  hour  flights  avg_delay
# 0               ABE     6      814   0.324324
# 1               ABE     7       29  -8.206897
# 2               ABE     9       15  -3.333333
# 3               ABE    11      135   8.022222
# 4               ABE    12      317   6.100946
# ...             ...   ...      ...        ...
# 4241            YUM    15      188   2.324468
# 4242            YUM    16      110   4.754545
# 4243            YUM    17       24  20.708333
# 4244            YUM    18      154   2.681818
# 4245            YUM    19       99   3.545455
#
# [4246 rows x 4 columns]

# %%
fig = px.scatter(
    airport_hour_df,
    x='flights',
    y='avg_delay',
    color='hour',
    trendline='ols',
    opacity=0.4,
    hover_data = {'ORIGIN_AIRPORT': True}
)

fig.show()

# %%
fig = px.scatter(
    airport_hour_df,
    x='hour',
    y='avg_delay',
    color='flights',
    trendline='ols',
    opacity=0.4,
    hover_data = {'ORIGIN_AIRPORT': True}
)

fig.show()

# %%
airport_hour_df['traffic_bin'] = pd.cut(
    airport_hour_df['flights'],
    bins=20
)

congestion_df = (
    airport_hour_df
    .groupby('traffic_bin')['avg_delay']
    .mean()
)

congestion_df.plot()
# Out:
# <Axes: xlabel='traffic_bin'>

# %%
px.density_heatmap(
    airport_hour_df,
    x='hour',
    y='ORIGIN_AIRPORT',
    z='avg_delay'
)

# %%
airport_hour_df = (
    filtered_flights
    .assign(
        hour = filtered_flights['SCHEDULED_DEPARTURE'] // 100,
        delayed = filtered_flights['ARRIVAL_DELAY'] > 0
    )
    .groupby(['ORIGIN_AIRPORT','hour'])
    .agg(
        flights=('FLIGHT_NUMBER','size'),
        avg_delay=('ARRIVAL_DELAY', lambda x: x[x > 0].mean()),
        delay_rate=('delayed','mean')
    )
    .reset_index()
)

# %%
airport_curves = (
    airport_hour_df
    .groupby('ORIGIN_AIRPORT')
    .apply(
        lambda x: x.sort_values('flights')
    )
)

# %%
fig = px.scatter(
    airport_hour_df,
    x='flights',
    y='delay_rate',
    color='ORIGIN_AIRPORT',
    opacity=0.4
)

fig.show()

# %%
thresholds = (
    airport_hour_df
    .groupby('ORIGIN_AIRPORT')
    .apply(
        lambda x: x.loc[
            x['delay_rate'] > x['delay_rate'].median() * 1.5,
            'flights'
        ].min()
    )
)

# %%
airport_hour_df[airport_hour_df['ORIGIN_AIRPORT']=='ABE']
# Out:
#   ORIGIN_AIRPORT  hour  flights  avg_delay  delay_rate
# 0            ABE     6      895  34.777311    0.265922
# 1            ABE     7       29  43.000000    0.068966
# 2            ABE     9       20  12.428571    0.350000
# 3            ABE    11      141  37.280702    0.404255
# 4            ABE    12      381  34.901408    0.372703
# 5            ABE    13      132  29.000000    0.340909
# 6            ABE    14       48  47.750000    0.083333
# 7            ABE    15       16  13.000000    0.250000
# 8            ABE    16      315  37.781955    0.422222
# 9            ABE    17      489  39.553191    0.576687

# %%
thresholds
# Out:
# ORIGIN_AIRPORT
# ABE    489.0
# ABI      4.0
# ABQ     12.0
# ABR      1.0
# ABY      3.0
#        ...
# WRG      NaN
# WYS     78.0
# XNA      NaN
# YAK      NaN
# YUM      NaN
# Length: 322, dtype: float64
