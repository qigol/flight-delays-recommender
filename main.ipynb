# %% [markdown]
# ### Data Download

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("usdot/flight-delays", output_dir="./data")

print("Path to dataset files:", path)
# Out:
# Downloading to ./data\1.archive...
# 100%|██████████| 191M/191M [00:10<00:00, 19.0MB/s]
# Extracting files...
# Path to dataset files: ./data

# %% [markdown]
# ## Basic

# %% [markdown]
# ## Intermediate

# %% [markdown]
# ## Advanced
